# %%
import pandas as pd
import os

df = pd.DataFrame()
df = pd.concat([pd.read_csv("./ejercicio_Parte_"+str(i)+".csv") for i in range(1,11)])

# %%
df.head()
# Out:
#     Dias     Ciudad  Don Limpio  Scotch Brite  Saimaza  Ariel  Mistol  Fairy  \
# 0  Lunes  Barcelona         716           269      193     30     542      6
# 1  Lunes  Barcelona         512           124      302     97     567     18
# 2  Lunes  Barcelona         148           501        9     57     925     96
# 3  Lunes  Barcelona          28           127      453     51     964     27
# 4  Lunes  Barcelona         674           431      241    133     404    110
#
#    Cola Cao  CristaSol  ...  Colhogar  Superglue  Orbit  Cleesa  Gallo  \
# 0       396        183  ...       332      450.0   1201     214   1019
# 1       492        571  ...        91      362.0    543     317   1007
# 2       133        645  ...        86      491.0    571      65    995
# 3       278        311  ...        14      505.0    697     543   1017
# 4       265        249  ...       135      487.0    585     257   1071
#
#    Denenes  Kleenex  Calvo  Isabel  Gallina_Blanca
# ...

# %%
df.describe()
# Out:
#           Don Limpio   Scotch Brite        Saimaza          Ariel  \
# count  600000.000000  600000.000000  600000.000000  600000.000000
# mean      243.838665     282.717625     254.856348     303.827417
# std       200.690126     221.264890     206.453861     220.737717
# min         1.000000       1.000000       1.000000       1.000000
# 25%        88.000000     101.000000      92.000000     124.000000
# 50%       185.000000     223.000000     197.000000     255.000000
# 75%       350.000000     424.000000     371.000000     446.000000
# max       957.000000     991.000000     981.000000     995.000000
#
#               Mistol          Fairy       Cola Cao      CristaSol  \
# count  600000.000000  600000.000000  600000.000000  600000.000000
# mean      261.790893     267.439270     283.505597     291.976770
# std       213.716730     211.582188     215.290741     216.810524
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df.groupby(["Dias","Ciudad"]).mean()
# Out:
#                      Don Limpio  Scotch Brite     Saimaza       Ariel  \
# Dias      Ciudad
# Jueves    Sevilla    147.131320    224.603640  333.857480  415.131040
#           Valencia   245.908467    278.208627  212.970920  306.887560
# Lunes     Barcelona  277.433387    230.311133  225.268800  336.898440
#           Madrid     321.797160    440.145120  296.242200  291.592000
# Martes    Granada    323.922020    366.944340  232.094780  268.732200
#           Madrid     238.877440    287.053840  274.794240  328.485800
# Miercoles Cuenca     258.087867    260.522907  217.996027  258.602827
#           Granada    339.577000    315.577440  269.059680  312.343680
# Sabado    Orinoco    194.750333    265.698547  320.864947  318.820347
#           Palermo    197.307400    320.790800  272.172840  309.847680
# Viernes   Palermo    162.642300    276.996080  308.664600  333.102640
#           Sevilla    233.445700    258.946920  191.405420  219.337400
#
# ...

# %%
df.corr()
# Out:
# /var/folders/ky/1wd728kj3z34yrqzyh1m58p00000gn/T/ipykernel_1633/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Don Limpio  Scotch Brite   Saimaza     Ariel    Mistol  \
# Don Limpio          1.000000      0.005777  0.001366 -0.006920  0.096023
# Scotch Brite        0.005777      1.000000  0.075569 -0.038186  0.037487
# Saimaza             0.001366      0.075569  1.000000  0.069217  0.019030
# Ariel              -0.006920     -0.038186  0.069217  1.000000  0.020673
# Mistol              0.096023      0.037487  0.019030  0.020673  1.000000
# Fairy               0.046795     -0.088900  0.039692  0.037093  0.055346
# Cola Cao           -0.006546      0.007416 -0.027270  0.016082 -0.031241
# CristaSol          -0.071043      0.011224  0.044998 -0.019637  0.016807
# ...

# %%
#print(df.loc[2, 'Ciudad'])
ciudades= df['Ciudad'].unique()
productos=[]

num_columns= len(df.columns)

productos=list(df.columns.values)
productos.remove('Dias')
# Out:
# ['Ciudad', 'Don Limpio', 'Scotch Brite', 'Saimaza', 'Ariel', 'Mistol', 'Fairy', 'Cola Cao', 'CristaSol', 'Mimosin', 'El Pozo', 'KH-7', 'Colgate', 'Sensodine', 'Listerine', 'Mousel', 'H&S', 'Pantene', 'Valor', 'Nelly', 'Matutano', 'Nivea', 'Loreal', 'Duracell', 'Campofrio', 'ZumoSol', 'Monster', 'Veet', 'Gillete', 'Coca_Cola', 'Pepsi', 'Puleva', 'Pascual', 'Cuetara', 'Casa_Tarradellas', 'Danone', 'Garcia_Vaquero', 'Lays', 'Floret', 'Apis', 'La_Piara', 'Fontaneda', 'Dodot', 'Colhogar', 'Superglue', 'Orbit', 'Cleesa', 'Gallo', 'Denenes', 'Kleenex', 'Calvo', 'Isabel', 'Gallina_Blanca']

# %%
df_mean=pd.DataFrame()
for i in range(len(productos)):
    df_mean[productos[i]]=None
df_mean['Ciudad']=ciudades

df_mean_2=pd.DataFrame()
df_mean_2=df.mean()

#df["Don Limpio"].mean()

#print(df_mean)
#precio_medio = print(df["Don Limpio"].mean())
